# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
from bb_filters.nodes.cluster.cluster_slalom_tfs import get_slalom_centroids

# %%
spread = 0.5
sample_points = np.vstack(
    [
        np.array([0.0, 0.0]) + (np.random.rand(100, 2) - 0.5) * spread,
        np.array([-0.5, 2.0]) + (np.random.rand(100, 2) - 0.5) * spread,
        np.array([0.5, 4.0]) + (np.random.rand(2, 2) - 0.5) * spread,
    ]
)
plt.scatter(
    sample_points[:, 0], sample_points[:, 1], s=10, c="blue", label="Data Points"
)
theta, centroids = get_slalom_centroids(sample_points, num_centroids=3)
plt.scatter(
    centroids[:, 0], centroids[:, 1], s=100, c="red", label="Centroids", marker="x"
)
